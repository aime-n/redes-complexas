# %% [markdown]
# # **Projeto de Classificação de Redes**

# %% [markdown]
# ## **1 - Medidas**

# %% [markdown]
# ### Para caracterizar as redes decidimos por utilizar as seguintes medidas:
#  - #### Average Degree
#  - #### Variance Degree
#  - #### Second Moment
#  - #### Average Clustering
#  - #### Average Shortest Path Length
#  - #### Degree Assortativity Coefficient
#  - #### Average closeness centrality
#  - #### Average betweenness centrality
#  - #### Average eigenvector centrality
#  - #### Average PageRank
#  - #### Modularity by Louvrain Method

# %%
def measures(G, p = False):
    
   
    d = {
        'N' : len(G),
        'M' : G.number_of_edges(),
        'mean' : momment_of_degree_distribution(G,1),
        'var' : momment_of_degree_distribution(G,2) - momment_of_degree_distribution(G,1)**2,
        'K2' : momment_of_degree_distribution(G,2),
        'av_cl' : nx.average_clustering(G),
        'l' : nx.average_shortest_path_length(G),
        'assor' : nx.degree_assortativity_coefficient(G),
        'entropy': shannon_entropy(G)
       
    }
    
    text = f"""
    Description of the Graph: 
    
        - Number of Nodes : {d['N']:.2f}
        - Number of Edges: {d['M']:.2f}
        - Average Degree: {d['mean']:.2f}
        - Degree Variance: {d['var']:.2f}
        - Second Momement: {d['K2']:.2f}
        - Average Clustering: {d['av_cl']:.2f}
        - Average Shortest Path Length: {d['l']:.2f}
        - Degree Assortativity Coefficient: {d['assor']:.2f}
        - Shannon Entropy: {d['entropy']:.2f}
        
    """
    if p:
        print(text)
    
    return d

# %%
import graph_tool.all as gt
g = gt.collection.ns["marvel_partnerships"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-0b5e78279340> in <module>
# ----> 1 import graph_tool.all as gt
#       2 g = gt.collection.ns["marvel_partnerships"]
#
# ModuleNotFoundError: No module named 'graph_tool'

# %% [markdown]
# ## **Redes**

# %% [markdown]
# ## Nome da primeira rede e link

# %%
zachary = nx.read_edgelist('./data/lesmis.txt', nodetype = int, data = (('weight',float),))

# %%
positions = nx.spring_layout(zachary)

# %%
nx.draw(zachary, pos = positions, node_color = 'lightblue', with_labels = True)
# Out:
# /home/aime/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
d = measures(zachary, True)
# Out:
#     Description of the Graph:
#
#         - Number of Nodes : 77.00
#         - Number of Edges: 254.00
#         - Average Degree: 6.60
#         - Degree Variance: 36.01
#         - Second Momement: 79.53
#         - Average Clustering: 0.57
#         - Average Shortest Path Length: 2.64
#         - Degree Assortativity Coefficient: -0.17
#         - Shannon Entropy: 3.60

# %% [markdown]
# ## **Amostragem**

# %% [markdown]
# ### **Modelos**

# %%
def BA(N, k, seed):
    
    m = int(k/2)

    return nx.barabasi_albert_graph(N, m)

# %%
def ER(N, k, seed):
    
    p = k/(N - 1)
    
    return clean_graph(nx.gnp_random_graph(N, p))

# %%
def SW(N, k, seed, p = 0.1):
    
    return nx.watts_strogatz_graph(N, int(k), p)

# %%
def sample(N, K, models, labels, col_names, size = 30):
    
    attr = []
    
    for i in np.arange(size):
        for model, label in zip(models, labels):
            
            attr.append(list(measures(model(N, K, i+10)).values())+[label])
            
    attr = np.array(attr)
    
    df = pd.DataFrame(attr, columns = col_names)
    
    return df

# %%
col_names = ['N', 'M', 'mean', 'var', 'K2', 'av_cl', 'l','assor','entropy', 'label']

df = sample(d['N'], d['mean'], [BA, ER, SW],['BA', 'ER', 'SW'], col_names, 30)

# %%
df
# Out:
#      N    M                mean                  var                  K2  \
# 0   77  222   5.766233766233766   21.633665036262435   54.88311688311688
# 1   77  252   6.545454545454545   5.9362455726092165   48.77922077922078
# 2   77  231                 6.0  0.49350649350649434  36.493506493506494
# 3   77  222   5.766233766233766    16.17911958171699   49.42857142857143
# 4   77  243   6.311688311688312    4.214538708045204   44.05194805194805
# ..  ..  ...                 ...                  ...                 ...
# 85  77  250  6.4935064935064934   7.1330747174903095    49.2987012987013
# 86  77  231                 6.0   0.5974025974025992    36.5974025974026
# 87  77  222   5.766233766233768   24.179119581716968   57.42857142857143
# 88  77  286   7.428571428571428    6.530612244897966  61.714285714285715
# 89  77  231   5.999999999999999   0.6233766233766289   36.62337662337662
#
#                   av_cl                   l                  assor  \
# 0   0.22571091853388503   2.479494190020506   -0.15376264342578294
# 1   0.07473284291466108  2.4859876965140124   0.059198964018127014
# 2   0.43354978354978363   3.417293233082707    -0.1239319620253247
# 3   0.15400228426544216   2.527341079972659   -0.13355159697864719
# 4   0.09174865538501902  2.5382775119617227   -0.05764248999530963
# ..                  ...                 ...                    ...
# 85  0.09496564042018586  2.4948735475051262   -0.10019241901686987
# 86  0.40865800865800833   3.215311004784689  -0.009720772442587542
# 87  0.18551801556637545  2.4381408065618593     -0.182701116000669
# 88   0.0964868464868465   2.359535201640465    0.03940886699507423
# 89    0.446093588950732  3.2334244702665753    0.09450084602368206
#
#                entropy label
# 0   2.9344742580791325    BA
# 1   3.1748618649206737    ER
# 2   1.5083356452133971    SW
# 3   2.9761782582172396    BA
# 4     2.93599475545915    ER
# ..                 ...   ...
# 85  3.3142921390570543    ER
# 86  1.6283286653930003    SW
# 87  2.7568466979128585    BA
# 88  3.2281520655347222    ER
# 89  1.6418615840422723    SW
#
# [90 rows x 10 columns]

# %% [markdown]
# ## **Classificação**

# %%
def knn(x, y, attr, k = 5, pca_r = False, n_c = 2):
    
    X = x.to_numpy()
    Y = y.to_numpy()
    
    scaler = StandardScaler().fit(X)
    
    X = scaler.transform(X)
    
    attr = np.array(attr)
    
    attr = attr.reshape(1,len(attr)) 
    attr = scaler.transform(attr)
    
    if pca_r:

        pca = PCA(n_components = n_c)
        pca.fit(X)
            
        exple = pca.explained_variance_ratio_
        
        X = pca.transform(X)
        attr =  pca.transform(attr)
        
        plot_with_labels(X, y, fit = attr)
        
        print(f'Explained Variance Ratio: {exple.sum()}')
    
    model = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean')
    model.fit(X,Y)
    
    return model.predict(attr)

# %%
knn(df.iloc[:, 2:9], df.iloc[:, 9], list(d.values())[2:], pca_r = True, n_c = 3)
# Out:
# Explained Variance Ratio: 0.9609525955371663
# array(['BA'], dtype=object)

# %% [markdown]
# ## **Variáveis Relevantes**

# %%
def most_relevants(x, y):
    
    X = x.to_numpy()
    Y = y.to_numpy()
    
    model = RandomForestClassifier(random_state = 37)
    model.fit(X,Y)
    
    random_forest = pd.Series(model.feature_importances_, index=x.columns)
    random_forest.sort_values().plot(kind='barh')

# %%
most_relevants(df.iloc[:, 2:9], df.iloc[:, 9])

# %% [markdown]
# ## **Funções Auxiliares**

# %%
def plot_with_labels(X, labels, fit = [[],[]], title = ''):
    
    label_filters, label_values = filters(labels)
        
    plt.figure(figsize = (8, 8))

    for f, v in zip(label_filters, label_values):
        plt.plot(X[f][:, 0], X[f][:, 1], 'o', label = v)
        
    plt.plot(fit[:,0], fit[:, 1], 'o', c = 'red',  label = 'To Predict')

    plt.xlabel('PC-1')
    plt.ylabel('PC-2')
    
    plt.title(title)
    
    plt.legend()

# %%
def filters(labels):
    
    values = labels.unique()
    
    n = len(values)
    
    f = []
    
    for v in values:
        
        f.append(labels == v)
    
    return f, values

# %%
def shannon_entropy(G):
    
    k, Pk = degree_distribution(G)
    
    H = 0
    
    for p in Pk:
        
        if p > 0:
            
            H -= p*np.log2(p)
    
    return H

# %%
def momment_of_degree_distribution(G, m):
    
    k, Pk = degree_distribution(G)
    
    M = sum((k**m)*Pk)
    
    return M

# %%
def degree_distribution(G):
    
    vk = np.array(list(dict(G.degree()).values()))
    
    maxk = vk.max()
    minK = vk.min()
    
    kvalues = np.arange(maxk + 1)
    Pk = np.zeros(maxk + 1)
    
    for k in vk:
        
        Pk[k] += 1
        
    Pk = Pk/Pk.sum()
    
    return kvalues, Pk

# %%
 def modularity(G, c):
        
    A = nx.adjacency_matrix(G)
        
    N = len(G)
    M = G.number_of_edges()
        
    Q = 0
        
    for i in np.arange(0,N):
        
        ki = len(list(G.neighbors(i)))
            
        for j in np.arange(0,N):
                
            if(c[i]==c[j]):
                    
                kj = len(list(G.neighbors(j)))
                Q = Q + A[i,j]-(ki*kj)/(2*M)
                
    Q = Q/(2*M)
    
    return Q

# %%
def description(G, p = False):
    
    d = {
        'N' : len(G),
        'M' : G.number_of_edges(),
        'mean' : momment_of_degree_distribution(G,1),
        'var' : momment_of_degree_distribution(G,2) - momment_of_degree_distribution(G,1)**2,
        'K2' : momment_of_degree_distribution(G,2),
        'av_cl' : nx.average_clustering(G),
        'l' : nx.average_shortest_path_length(G),
        'assor' : nx.degree_assortativity_coefficient(G)
    }
    
    text = f"""
    Description of the Graph: 
    
        - Number of Nodes : {d['N']:.2f}
        - Number of Edges: {d['M']:.2f}
        - Average Degree: {d['mean']:.2f}
        - Degree Variance: {d['var']:.2f}
        - Second Momement: {d['K2']:.2f}
        - Average Clustering: {d['av_cl']:.2f}
        - Average Shortest Path Length: {d['l']:.2f}
        - Degree Assortativity Coefficient: {d['assor']:.2f}
    """
    if p:
        print(text)
    
    return d

# %%
def clean_graph(G, remove_edges = True):
    
    G = G.to_undirected()
    nodes_original = G.nodes
    
    if remove_edges:
        
        G.remove_edges_from(nx.selfloop_edges(G))
    
    G_cc = sorted(nx.connected_components(G), key = len, reverse =True)
    G = G.subgraph(G_cc[0])
    G = nx.convert_node_labels_to_integers(G, first_label = 0 )
    
    return G

# %% [markdown]
# ## **Bibliotecas**

# %%
import numpy as np

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
from community import community_louvain

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA

# %% [markdown]
# ## Conclusão
#
# A hipótese inicial levantada de que as redes do mesmo tipo seriam classificadas no mesmo modelo foi parcialmente verificada. Pois as redes de mesmo tipo não foram unanimamente classificadas. Também foi avaliado o papel dos atributos na classificação.
#
# Nos casos avaliados de tipos de rede social, biológica e tecnológica, apenas uma rede diferiu na sua classificação, dentre as três avaliadas de cada categoria. As outras duas foram categorizadas no mesmo modelo. O que pode ser devido ao fato de que seus atributos, em algumas redes, ficaram distantes dos modelos avaliados, sendo eles Barabási-Albert, Erdős–Rényi e Small World. Isto pode indicar que tal rede não pertence a nenhum dos modelos abordados. Além disso, nenhuma rede foi classificada como Small World. Isto era esperado, já que redes reais tem a característica de aprensentar clusters, e redes Small World não.
#
# A partir dos gráficos obtidos através do método de seleção de atributos Randon Forest, não foi observado que alguma variável tivesse papel principal na discriminação entre os modelos, se disconsidermos o grau médio e sua variância, que deveriam ser constantes.
